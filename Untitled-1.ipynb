# %%
#importing the packages
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
import sklearn.metrics as metrics

# %%
Diabetes= pd.read_csv('D:/python/archive (12)/diabetes_data_upload.csv')

# %% [markdown]
# Split Data

# %%
Diabetes.head(10)
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
# 5   55   Male      Yes        Yes                 No      Yes        Yes
# 6   57   Male      Yes        Yes                 No      Yes        Yes
# 7   66   Male      Yes        Yes                Yes      Yes         No
# 8   67   Male      Yes        Yes                 No      Yes        Yes
# 9   70   Male       No        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# ...

# %% [markdown]
# Preparing the Dataset
# Checking for missing/null values.
# Examining the information in the columns.
# The fundamental statistics of the numeric column.
# Imputing/encoding the data (In this case, we'll convert Yes/No at the end because 0 and 1 in all the columns can be confusing).

# %%
Diabetes.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Polyuria              0
# Polydipsia            0
# sudden weight loss    0
# weakness              0
# Polyphagia            0
# Genital thrush        0
# visual blurring       0
# Itching               0
# Irritability          0
# delayed healing       0
# partial paresis       0
# muscle stiffness      0
# Alopecia              0
# Obesity               0
# class                 0
# dtype: int64

# %%
Diabetes.isna().sum()
# Out:
# Age                   0
# Gender                0
# Polyuria              0
# Polydipsia            0
# sudden weight loss    0
# weakness              0
# Polyphagia            0
# Genital thrush        0
# visual blurring       0
# Itching               0
# Irritability          0
# delayed healing       0
# partial paresis       0
# muscle stiffness      0
# Alopecia              0
# Obesity               0
# class                 0
# dtype: int64

# %%
Diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 520 non-null    int64
#  1   Gender              520 non-null    object
#  2   Polyuria            520 non-null    object
#  3   Polydipsia          520 non-null    object
#  4   sudden weight loss  520 non-null    object
#  5   weakness            520 non-null    object
#  6   Polyphagia          520 non-null    object
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    object
#  9   Itching             520 non-null    object
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    object
#  12  partial paresis     520 non-null    object
#  13  muscle stiffness    520 non-null    object
#  14  Alopecia            520 non-null    object
# ...

# %%
Diabetes.describe()
# Out:
#               Age
# count  520.000000
# mean    48.028846
# std     12.151466
# min     16.000000
# 25%     39.000000
# 50%     47.500000
# 75%     57.000000
# max     90.000000

# %% [markdown]
# EDA ( Explolatory Data Analysis)
# Gender Distribution

# %% [markdown]
# pip show nbformat

# %%
pip install show nbformat
# Out:
# ...
#      ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#       --------------------------------------- 0.0/2.3 MB 435.7 kB/s eta 0:00:06
#       --------------------------------------- 0.0/2.3 MB 326.8 kB/s eta 0:00:07
#      - -------------------------------------- 0.1/2.3 MB 581.0 kB/s eta 0:00:04
#      - -------------------------------------- 0.1/2.3 MB 595.3 kB/s eta 0:00:04
#      -- ------------------------------------- 0.2/2.3 MB 701.4 kB/s eta 0:00:04
#      --- ------------------------------------ 0.2/2.3 MB 737.3 kB/s eta 0:00:03
#      ---- ----------------------------------- 0.2/2.3 MB 793.0 kB/s eta 0:00:03
#      ---- ----------------------------------- 0.3/2.3 MB 803.7 kB/s eta 0:00:03
#      ----- ---------------------------------- 0.3/2.3 MB 846.5 kB/s eta 0:00:03
#      ------ --------------------------------- 0.4/2.3 MB 849.3 kB/s eta 0:00:03
# ...

# %%
pip show nbformat
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: nbformat
